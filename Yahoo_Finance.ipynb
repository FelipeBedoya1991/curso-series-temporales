# %% [markdown]
# ## Yahoo Finance
# Si quieres tener los datos de precios de índices actualizados a día de hoy, lo puedes hacer de la siguiente manera. Estos datos han sido obtenidos mediante [Yahoo Finance](https://es.finance.yahoo.com/), una plataforma donde puedes ver, obtener, estudiar, analizar y comparar los precios de cierre de diferentes de acciones de los mercados financieros. La forma de obtener los datos de Yahoo Finance en Python es mediante el paquete `yfinance` que tendremos que instalar e importar.

# %%
# !pip install yfinance
import yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\felipe bedoya\anaconda3\lib\site-packages (0.1.55)
# Requirement already satisfied: pandas>=0.24 in c:\users\felipe bedoya\anaconda3\lib\site-packages (from yfinance) (1.0.1)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\felipe bedoya\anaconda3\lib\site-packages (from yfinance) (4.6.2)
# Requirement already satisfied: requests>=2.20 in c:\users\felipe bedoya\anaconda3\lib\site-packages (from yfinance) (2.22.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\felipe bedoya\anaconda3\lib\site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: numpy>=1.15 in c:\users\felipe bedoya\anaconda3\lib\site-packages (from yfinance) (1.18.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\felipe bedoya\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\felipe bedoya\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\felipe bedoya\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\felipe bedoya\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\felipe bedoya\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\felipe bedoya\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2.8)
# Requirement already satisfied: six>=1.5 in c:\users\felipe bedoya\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.24->yfinance) (1.14.0)

# %% [markdown]
# Para obtener los precios de cierre de los índices SP500, FTSE, DAX y NIKKEI, especificar los nombres, la fecha de inicio y fin, y el intervalo (diario=1d):

# %%
raw_data = yfinance.download (tickers = "^GSPC ^FTSE ^N225 ^GDAXI", start = "1994-01-07", 
                              end = "2020-05-17", interval = "1d", group_by = 'ticker', auto_adjust = True, treads = True)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
raw_data.tail()
# Out:
#                    ^N225                                                     \
#                     Open          High           Low         Close   Volume
# Date
# 2020-05-11  20333.730469  20534.880859  20285.039062  20390.660156  76200.0
# 2020-05-12  20413.230469  20457.369141  20293.970703  20366.480469  67700.0
# 2020-05-13  20140.919922  20329.890625  20056.460938  20267.050781  79500.0
# 2020-05-14  20140.490234  20185.000000  19902.929688  19914.779297  76900.0
# 2020-05-15  20149.789062  20198.250000  19832.880859  20037.470703  75200.0
#
#                   ^GDAXI                                            \
#                     Open          High           Low         Close
# Date
# 2020-05-11  10948.240234  10986.219727  10740.820312  10824.990234
# 2020-05-12  10777.740234  10886.009766  10772.580078  10819.500000
# 2020-05-13  10669.990234  10698.129883  10530.320312  10542.660156
# 2020-05-14  10418.040039  10474.080078  10160.889648  10337.019531
# 2020-05-15  10470.849609  10547.190430  10382.540039  10465.169922
#
#                                ^FTSE                                         \
#                  Volume         Open         High          Low        Close
# Date
# 2020-05-11   88080900.0  5936.000000  5999.100098  5898.299805  5939.700195
# 2020-05-12   88857600.0  5939.700195  6013.000000  5911.399902  5994.799805
# 2020-05-13  108739000.0  5994.799805  5994.799805  5893.399902  5904.100098
# 2020-05-14  133623600.0  5904.100098  5904.100098  5661.100098  5741.500000
# 2020-05-15  116082600.0  5741.500000  5837.899902  5741.500000  5799.799805
#
#                                 ^GSPC                                         \
#                   Volume         Open         High          Low        Close
# Date
# 2020-05-11  1.041394e+09  2915.459961  2944.250000  2903.439941  2930.189941
# 2020-05-12  9.397677e+08  2939.500000  2945.820068  2869.590088  2870.120117
# 2020-05-13  1.055706e+09  2865.860107  2874.139893  2793.149902  2820.000000
# 2020-05-14  1.152460e+09  2794.540039  2852.800049  2766.639893  2852.500000
# 2020-05-15  9.274333e+08  2829.949951  2865.010010  2816.780029  2863.699951
#
#
#                   Volume
# Date
# 2020-05-11  4.807320e+09
# 2020-05-12  5.107710e+09
# 2020-05-13  6.143130e+09
# 2020-05-14  5.641920e+09
# 2020-05-15  5.477040e+09

# %%
df_comp=raw_data.copy()

# %% [markdown]
# Para cada día y cada precio obtenemos 4 datos, los precios de: apertura, máximo, bajo, cierre y volumen. Queremos los precios de cierre así que seleccionamos sólo la variable cierre para cada precio, los guardamos en 4 nuevas variables en el dataset y les ponemos los nombres del indice al que corresponden.

# %%
df_comp['spx'] = df_comp['^GSPC'].Close[:]
df_comp['dax'] = df_comp['^GDAXI'].Close[:]
df_comp['ftse'] = df_comp['^FTSE'].Close[:]
df_comp['nikkei'] = df_comp['^N225'].Close[:]

# %%
df_comp.head()
# Out:
#                    ^N225                                                   \
#                     Open          High           Low         Close Volume
# Date
# 1994-01-07  17842.980469  18131.410156  17787.480469  18124.009766    0.0
# 1994-01-10  18186.519531  18567.060547  18186.519531  18443.439453    0.0
# 1994-01-11  18481.849609  18671.669922  18373.039062  18485.250000    0.0
# 1994-01-12  18447.339844  18807.080078  18301.929688  18793.880859    0.0
# 1994-01-13  18770.380859  18823.380859  18548.750000  18577.259766    0.0
#
#                  ^GDAXI                                                ...  \
#                    Open         High          Low        Close Volume  ...
# Date                                                                   ...
# 1994-01-07  2218.959961  2227.639893  2201.820068  2224.949951    0.0  ...
# 1994-01-10  2231.840088  2238.010010  2222.000000  2225.000000    0.0  ...
# 1994-01-11  2225.429932  2235.610107  2225.179932  2228.100098    0.0  ...
# 1994-01-12  2227.120117  2227.790039  2182.060059  2182.060059    0.0  ...
# 1994-01-13  2171.500000  2183.709961  2134.100098  2142.370117    0.0  ...
#
#             ^FTSE       ^GSPC                                      \
#            Volume        Open        High         Low       Close
# Date
# 1994-01-07    0.0  467.089996  470.260010  467.029999  469.899994
# 1994-01-10    0.0  469.899994  475.269989  469.549988  475.269989
# 1994-01-11    0.0  475.269989  475.279999  473.269989  474.130005
# 1994-01-12    0.0  474.130005  475.059998  472.140015  474.170013
# 1994-01-13    0.0  474.170013  474.170013  471.799988  472.470001
#
#                                 spx          dax         ftse        nikkei
#                  Volume
# Date
# 1994-01-07  324920000.0  469.899994  2224.949951  3446.000000  18124.009766
# 1994-01-10  319490000.0  475.269989  2225.000000  3440.600098  18443.439453
# 1994-01-11  305490000.0  474.130005  2228.100098  3413.800049  18485.250000
# 1994-01-12  310690000.0  474.170013  2182.060059  3372.000000  18793.880859
# 1994-01-13  277970000.0  472.470001  2142.370117  3360.000000  18577.259766
#
# [5 rows x 24 columns]

# %% [markdown]
# Pre-procesado: eliminar las variables que sobran, arreglar la frecuencia a business days y rellenar datos faltantes.

# %%
df_comp = df_comp.iloc[1:]
del df_comp['^N225']
del df_comp['^GSPC']
del df_comp['^GDAXI']
del df_comp['^FTSE']
df_comp=df_comp.asfreq('b')
df_comp=df_comp.fillna(method='ffill')

# %%
df_comp.head()
# Out:
#                    spx          dax         ftse        nikkei
#
# Date
# 1994-01-10  475.269989  2225.000000  3440.600098  18443.439453
# 1994-01-11  474.130005  2228.100098  3413.800049  18485.250000
# 1994-01-12  474.170013  2182.060059  3372.000000  18793.880859
# 1994-01-13  472.470001  2142.370117  3360.000000  18577.259766
# 1994-01-14  474.910004  2151.050049  3400.600098  18973.699219
